# %% [markdown]
# ## **Project Name** - Sales Prediction Using Python
#
# ##### Project Type - Prediction
# ##### Name - Aryan Patel
# ##### Task - 5
# ##### Github Respo - https://github.com/aryanap11/OIBSIP
# #### Project Description -
#
# Sales prediction means predicting how much of a product people will buy based on factors
# such as the amount you spend to advertise your product, the segment of people you
# advertise for, or the platform you are advertising on about your product.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##  **1) READ DATASET**

# %%
df= pd.read_csv("Advertising.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# ##  **2) DATASET ANALYSIS**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Get size of dataset
df.size
# Out:
# 1000

# %%
# Get (rows,columns)
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
#Get number of duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# Get number of null values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
#Get statistical summary of dataset(numeric values)
df.describe().round(3)
# Out:
#        Unnamed: 0       TV    Radio  Newspaper    Sales
# count     200.000  200.000  200.000    200.000  200.000
# mean      100.500  147.042   23.264     30.554   14.022
# std        57.879   85.854   14.847     21.779    5.217
# min         1.000    0.700    0.000      0.300    1.600
# 25%        50.750   74.375    9.975     12.750   10.375
# 50%       100.500  149.750   22.900     25.750   12.900
# 75%       150.250  218.825   36.525     45.100   17.400
# max       200.000  296.400   49.600    114.000   27.000

# %% [markdown]
# ### Conclusion about the dataset

# %% [markdown]
# * The dataset contains advertising spending across TV, Radio, Newspaper and the corresponding sales.
# * There are 200 rows and 5 columns in the data.
# * Column names : 'Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'
# * No duplicate rows present in dataset.
# * No Null values present in dataset.

# %% [markdown]
# ## **3) DATA TRANSFORMATION**

# %%
# Removing the 'Unnamed: 0' column as it's of no use
df=df.drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ## **4) DATA VISUALIZATION**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ####  3.1 - Boxplot

# %%
# Boxplot to see outliers
sns.boxplot(df)
plt.show()

# %%
sns.boxplot(x=df['Newspaper'])
plt.title('Boxplot of Newspaper')
plt.show()

# %% [markdown]
# **Findings:** As we can see there are outliers in 'Newspaper' so we'll remove them

# %%
#Removing outliers
Q1 = df['Newspaper'].quantile(0.25)
Q3 = df['Newspaper'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# outliers
outliers = df[(df['Newspaper'] < lower_bound) | (df['Newspaper'] > upper_bound)]
print(outliers)

df_clean = df[(df['Newspaper'] >= lower_bound) & (df['Newspaper'] <= upper_bound)]
# Out:
#         TV  Radio  Newspaper  Sales
# 16    67.8   36.6      114.0   12.5
# 101  296.4   36.3      100.9   23.8

# %%
df_clean
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
df_clean.shape
# Out:
# (198, 4)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 198 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         198 non-null    float64
#  1   Radio      198 non-null    float64
#  2   Newspaper  198 non-null    float64
#  3   Sales      198 non-null    float64
# dtypes: float64(4)
# memory usage: 7.7 KB

# %% [markdown]
# #### 3.2 - Correlation Heatmap

# %%
# Correlation Heatmap to check for multicollinearity among independent/dependent variables

corrmat = df_clean.corr()
plt.figure(figsize=(8, 7))
sns.heatmap(corrmat,annot=True , square=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Correlation Heatmap to check for multicollinearity among independent/dependent variables
# ----> 3 corrmat = df_clean.corr()
#       4 plt.figure(figsize=(8, 7))
#       5 sns.heatmap(corrmat,annot=True , square=True)
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# #### Insights/conclusion form corelation chart
#
# * TV and Radio have stronger correlations with Sales (0.779 , 0.577) compared to Newspaper (0.220).
#
# * so for the training of model TV and Radio will be important features as they have significant impact on Sales.

# %% [markdown]
# #### 3.3 - Relationship between each independent variable and the dependent variable

# %%
# tv vs sales
sns.lmplot(x='TV', y='Sales', data=df_clean)

# %%
# radio vs sales 
sns.lmplot(x='Radio', y='Sales', data=df_clean)

# %%
# newspaper vs sales 
sns.lmplot(x='Newspaper',y= 'Sales', data=df_clean)

# %% [markdown]
#  ## **4) ML MODEL TRAINING**

# %%
# with tv radio and newspaper
x = df_clean[['TV','Radio','Newspaper']]
x.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
# Target
y=df_clean['Sales']
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %% [markdown]
# ### Splitting The Data Into Test And Train Data

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test  = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
import pandas as pd
from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## Model-1 Linear Regression

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression

LR = LinearRegression()
LR.fit(X_train , y_train )

y_pred  = LR .predict(X_test )
y_pred
# Out:
# array([14.01074388,  7.32660883, 16.91029923, 12.10494494, 10.32680801,
#        15.800589  , 12.86917345, 14.46182171, 10.88622651, 16.12070585,
#        22.89188978,  4.44772138, 14.47452338, 15.16779294, 13.08219004,
#        11.93756336,  7.38163825, 11.34017618,  9.97074394, 17.25257133,
#        20.92597453,  9.48506413,  8.89608111, 12.37384205,  9.35819552,
#        16.12716079, 12.20096627, 20.59655504, 21.36951517, 15.07208869,
#        23.2153892 , 20.87809592,  9.72208672, 24.06696712, 16.36688684,
#         7.97869287, 21.91262979, 13.29393385, 11.82322424,  9.07954633])

# %%
print('intercept: ',LR.intercept_)
print('coefficients: ',LR.coef_)
# Out:
# intercept:  2.7811975517715837
# coefficients:  [0.0448192  0.18851633 0.00639467]

# %%
# actual and predicted valus
act_pred = pd.DataFrame({'Actual':y_test.values.flatten(), 'Predict':y_pred.flatten()})
act_pred
# Out:
#     Actual    Predict
# 0     14.6  14.010744
# 1      8.4   7.326609
# 2     18.0  16.910299
# 3     11.7  12.104945
# 4      8.8  10.326808
# 5     16.0  15.800589
# 6      7.2  12.869173
# 7     15.5  14.461822
# 8      9.2  10.886227
# 9     16.6  16.120706
# 10    24.2  22.891890
# 11     6.9   4.447721
# 12    11.9  14.474523
# 13    15.5  15.167793
# 14    12.6  13.082190
# 15    13.2  11.937563
# 16     9.5   7.381638
# 17     9.5  11.340176
# 18    10.1   9.970744
# 19    17.1  17.252571
# 20    21.8  20.925975
# 21    10.3   9.485064
# 22    10.6   8.896081
# 23    12.9  12.373842
# 24    10.9   9.358196
# 25    15.9  16.127161
# 26    12.6  12.200966
# 27    22.6  20.596555
# 28    22.2  21.369515
# 29    14.9  15.072089
# 30    24.4  23.215389
# 31    20.8  20.878096
# 32     9.6   9.722087
# 33    25.4  24.066967
# 34    15.5  16.366887
# 35     9.7   7.978693
# 36    24.7  21.912630
# 37    12.9  13.293934
# 38    13.4  11.823224
# 39    10.6   9.079546

# %%
# Model Evaluation 
mae  = mean_absolute_error(y_test , y_pred )
mse  = mean_squared_error(y_test , y_pred )
rmse  = mse  ** 0.5
r2  = r2_score(y_test , y_pred )

evaluation= [mae,mse,rmse,r2]
score = pd.DataFrame(index = ['MAE', 'MSE', 'RMSE',  'R2'])
score['LR'] = evaluation

# %%
# Plot of actual and predicted values

plt.figure(figsize=(12,4))
plt.plot((y_pred))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.title('Actual and Predicted Sales', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Sales')

# %%
score
# Out:
#             LR
# MAE   1.177153
# MSE   2.432077
# RMSE  1.559512
# R2    0.909895

# %% [markdown]
# ## Model-2 Lasso Regression

# %%
# Lasso Regression
from sklearn.linear_model import Lasso

model = Lasso()
model.fit(X_train , y_train )

y_pred  = model.predict(X_test )

# %%
# Model Evaluation 
mae  = mean_absolute_error(y_test , y_pred )
mse  = mean_squared_error(y_test , y_pred )
rmse  = mse  ** 0.5
r2  = r2_score(y_test , y_pred )

evaluation= [mae,mse,rmse,r2]
score['Lasso'] = evaluation

# %%
# Plot of actual and predicted values

plt.figure(figsize=(12,4))
plt.plot((y_pred))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.title('Actual and Predicted Sales', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Sales')

# %%
score
# Out:
#             LR     Lasso
# MAE   1.177153  1.168965
# MSE   2.432077  2.372882
# RMSE  1.559512  1.540416
# R2    0.909895  0.912088

# %% [markdown]
# ## Model-3 Ridge Regression

# %%
# Ridge Regression
from sklearn.linear_model import Ridge

model = Ridge()
model.fit(X_train , y_train )

y_pred  = model.predict(X_test )

# %%
# Model Evaluation 
mae  = mean_absolute_error(y_test , y_pred )
mse  = mean_squared_error(y_test , y_pred )
rmse  = mse  ** 0.5
r2  = r2_score(y_test , y_pred )

evaluation= [mae,mse,rmse,r2]
score['Ridge'] = evaluation

# %%
# Plot of actual and predicted values

plt.figure(figsize=(12,4))
plt.plot((y_pred))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.title('Actual and Predicted Sales', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Sales')

# %%
score
# Out:
#             LR     Lasso     Ridge
# MAE   1.177153  1.168965  1.177161
# MSE   2.432077  2.372882  2.432081
# RMSE  1.559512  1.540416  1.559513
# R2    0.909895  0.912088  0.909894

# %% [markdown]
# ## Model-4 Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# DecisionTreeRegressor

DTR  = DecisionTreeRegressor()
DTR.fit(X_train , y_train )

y_pred  = DTR.predict(X_test )
y_pred
# Out:
# array([17. ,  9.7, 15.2, 12.8,  8. , 15.3,  6.6, 15. ,  8.5, 16.6, 25.4,
#         7.3, 12.3, 15.6, 14.7, 11.9,  9.4,  8. , 10.4, 19.4, 22.1, 10.5,
#         9.9, 11.9, 11.3, 15.6, 14.4, 23.2, 21.5, 16.6, 22.1, 19.7, 10.1,
#        25.5, 14.8,  9.7, 23.7, 14.1, 12.2,  9.9])

# %%
# actual and predicted valus
act_pred = pd.DataFrame({'Actual':y_test.values.flatten(), 'Predict':y_pred.flatten()})
act_pred
# Out:
#     Actual  Predict
# 0     14.6     17.0
# 1      8.4      9.7
# 2     18.0     15.2
# 3     11.7     12.8
# 4      8.8      8.0
# 5     16.0     15.3
# 6      7.2      6.6
# 7     15.5     15.0
# 8      9.2      8.5
# 9     16.6     16.6
# 10    24.2     25.4
# 11     6.9      7.3
# 12    11.9     12.3
# 13    15.5     15.6
# 14    12.6     14.7
# 15    13.2     11.9
# 16     9.5      9.4
# 17     9.5      8.0
# 18    10.1     10.4
# 19    17.1     19.4
# 20    21.8     22.1
# 21    10.3     10.5
# 22    10.6      9.9
# 23    12.9     11.9
# 24    10.9     11.3
# 25    15.9     15.6
# 26    12.6     14.4
# 27    22.6     23.2
# 28    22.2     21.5
# 29    14.9     16.6
# 30    24.4     22.1
# 31    20.8     19.7
# 32     9.6     10.1
# 33    25.4     25.5
# 34    15.5     14.8
# 35     9.7      9.7
# 36    24.7     23.7
# 37    12.9     14.1
# 38    13.4     12.2
# 39    10.6      9.9

# %%
# Model Evaluation 
mae  = mean_absolute_error(y_test , y_pred )
mse  = mean_squared_error(y_test , y_pred )
rmse  = mse  ** 0.5
r2  = r2_score(y_test , y_pred )

evaluation= [mae,mse,rmse,r2]
score['DTR'] = evaluation

# %%
# Plot of actual and predicted values

plt.figure(figsize=(12,4))
plt.plot((y_pred))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.title('Actual and Predicted Sales (DecisionTreeRegressor)', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Sales (DecisionTreeRegressor)')

# %%
score
# Out:
#             LR     Lasso     Ridge       DTR
# MAE   1.177153  1.168965  1.177161  0.927500
# MSE   2.432077  2.372882  2.432081  1.367750
# RMSE  1.559512  1.540416  1.559513  1.169508
# R2    0.909895  0.912088  0.909894  0.949327

# %% [markdown]
# ## Model-5 Random Forest Regressor

# %%
# Train the model
from sklearn.ensemble import RandomForestRegressor

RFR  = RandomForestRegressor()
RFR.fit(X_train , y_train )

y_pred  = RFR.predict(X_test )
y_pred
# Out:
# array([15.956,  9.295, 17.175, 12.572,  8.195, 15.007,  6.913, 15.562,
#         8.278, 17.116, 25.147,  7.245, 12.193, 15.492, 12.749, 12.656,
#         9.472,  7.894, 10.639, 17.597, 22.353, 10.441, 10.017, 12.921,
#        11.242, 15.919, 13.988, 22.42 , 21.103, 16.451, 23.404, 20.308,
#        10.424, 25.267, 15.227,  9.513, 23.133, 14.057, 12.805,  9.994])

# %%
# actual and predicted valus
act_pred = pd.DataFrame({'Actual':y_test.values.flatten(), 'Predict':y_pred.flatten()})
act_pred
# Out:
#     Actual  Predict
# 0     14.6   15.956
# 1      8.4    9.295
# 2     18.0   17.175
# 3     11.7   12.572
# 4      8.8    8.195
# 5     16.0   15.007
# 6      7.2    6.913
# 7     15.5   15.562
# 8      9.2    8.278
# 9     16.6   17.116
# 10    24.2   25.147
# 11     6.9    7.245
# 12    11.9   12.193
# 13    15.5   15.492
# 14    12.6   12.749
# 15    13.2   12.656
# 16     9.5    9.472
# 17     9.5    7.894
# 18    10.1   10.639
# 19    17.1   17.597
# 20    21.8   22.353
# 21    10.3   10.441
# 22    10.6   10.017
# 23    12.9   12.921
# 24    10.9   11.242
# 25    15.9   15.919
# 26    12.6   13.988
# 27    22.6   22.420
# 28    22.2   21.103
# 29    14.9   16.451
# 30    24.4   23.404
# 31    20.8   20.308
# 32     9.6   10.424
# 33    25.4   25.267
# 34    15.5   15.227
# 35     9.7    9.513
# 36    24.7   23.133
# 37    12.9   14.057
# 38    13.4   12.805
# 39    10.6    9.994

# %%
# Model Evaluation 
mae  = mean_absolute_error(y_test , y_pred )
mse  = mean_squared_error(y_test , y_pred )
rmse  = mse  ** 0.5
r2  = r2_score(y_test , y_pred )

evaluation= [mae,mse,rmse,r2]
score['RFR'] = evaluation

# %%
# Plot of actual and predicted values

plt.figure(figsize=(12,4))
plt.plot((y_pred))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.title('Actual and Predicted Sales (RandomForestRegressor)', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Sales (RandomForestRegressor)')

# %%
score
# Out:
#             LR     Lasso     Ridge       DTR       RFR
# MAE   1.177153  1.168965  1.177161  0.927500  0.624850
# MSE   2.432077  2.372882  2.432081  1.367750  0.601994
# RMSE  1.559512  1.540416  1.559513  1.169508  0.775883
# R2    0.909895  0.912088  0.909894  0.949327  0.977697

# %% [markdown]
# ## Model-6 Support Vector Regressor

# %%
# Train the model
from sklearn.svm import SVR

SVR  = SVR()
SVR.fit(X_train , y_train )

y_pred  = SVR.predict(X_test )
y_pred
# Out:
# array([14.63187601,  8.65150457, 16.24395389, 13.89024124,  8.73308591,
#        15.35185943,  9.1943873 , 15.32738951,  9.15009018, 16.2105523 ,
#        19.82269093,  7.13274544, 15.90651796, 15.74635929, 12.35141978,
#        12.79097969,  9.90280999,  9.03859644,  9.37691197, 17.67052203,
#        18.98369233, 11.56122342, 10.77042121, 13.66024786, 10.23539531,
#        16.09529915, 13.57038657, 19.14750132, 19.35953536, 15.85319656,
#        19.175568  , 18.44067661,  9.21430003, 19.13072139, 16.48080036,
#        10.15319025, 19.24689969, 15.1597682 , 12.98456411, 10.65746918])

# %%
# actual and predicted valus
act_pred = pd.DataFrame({'Actual':y_test.values.flatten(), 'Predict':y_pred.flatten()})
act_pred
# Out:
#     Actual    Predict
# 0     14.6  14.631876
# 1      8.4   8.651505
# 2     18.0  16.243954
# 3     11.7  13.890241
# 4      8.8   8.733086
# 5     16.0  15.351859
# 6      7.2   9.194387
# 7     15.5  15.327390
# 8      9.2   9.150090
# 9     16.6  16.210552
# 10    24.2  19.822691
# 11     6.9   7.132745
# 12    11.9  15.906518
# 13    15.5  15.746359
# 14    12.6  12.351420
# 15    13.2  12.790980
# 16     9.5   9.902810
# 17     9.5   9.038596
# 18    10.1   9.376912
# 19    17.1  17.670522
# 20    21.8  18.983692
# 21    10.3  11.561223
# 22    10.6  10.770421
# 23    12.9  13.660248
# 24    10.9  10.235395
# 25    15.9  16.095299
# 26    12.6  13.570387
# 27    22.6  19.147501
# 28    22.2  19.359535
# 29    14.9  15.853197
# 30    24.4  19.175568
# 31    20.8  18.440677
# 32     9.6   9.214300
# 33    25.4  19.130721
# 34    15.5  16.480800
# 35     9.7  10.153190
# 36    24.7  19.246900
# 37    12.9  15.159768
# 38    13.4  12.984564
# 39    10.6  10.657469

# %%
# Model Evaluation 
mae  = mean_absolute_error(y_test , y_pred )
mse  = mean_squared_error(y_test , y_pred )
rmse  = mse  ** 0.5
r2  = r2_score(y_test , y_pred )

evaluation= [mae,mse,rmse,r2]
score['SVR'] = evaluation

# %%
# Plot of actual and predicted values

plt.figure(figsize=(12,4))
plt.plot((y_pred))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.title('Actual and Predicted Sales (SVR)', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Actual and Predicted Sales (SVR)')

# %%
score
# Out:
#             LR     Lasso     Ridge       DTR       RFR       SVR
# MAE   1.177153  1.168965  1.177161  0.927500  0.624850  1.429315
# MSE   2.432077  2.372882  2.432081  1.367750  0.601994  4.756472
# RMSE  1.559512  1.540416  1.559513  1.169508  0.775883  2.180934
# R2    0.909895  0.912088  0.909894  0.949327  0.977697  0.823779

# %% [markdown]
# ### Conclusion
#
# * In this task, I have used the Advertising Dataset to predict sales based on TV, Radio, and Newspaper advertising budgets.
#
# * I performed an analysis and visualization of the dataset to understand the relationships between features and identify outliers.
# * I trained several models: Linear Regression, Decision Tree Regressor, Random Forest Regressor, and Support Vector Regressor (SVR).
# * The Random Forest Regressor achieved the best performance with an R-squared value of 0.978260, indicating very high accuracy.
#
# * I created a dataframe of actual and predicted values for each model to demonstrate their effectiveness.
# * Finally, I visualized the actual and predicted sales values, showing a close match for the best-performing models and confirming their reliability.
